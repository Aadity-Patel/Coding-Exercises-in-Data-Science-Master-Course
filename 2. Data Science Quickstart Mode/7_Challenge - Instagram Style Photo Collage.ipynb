# %%
import cv2

# %%
import numpy as np

# %%
# Gap for future use
import matplotlib.pyplot as plt

# %%
img_1 = cv2.imread('7_1_top_left.jpg')
img_2 = cv2.imread('7_2_top_right.jpg')
img_3 = cv2.imread('7_3_bottom_left.jpg')
img_4 = cv2.imread('7_4_bottom_right.jpg')
img_5 = cv2.imread('7_5_center.jpeg')

# %%
img_1.shape
# Out:
# (570, 570, 3)

# %%
rs_img_1 = cv2.resize(img_1, (200,200))

# %%
rs_img_2 = cv2.resize(img_2, (200,200))

# %%
rs_img_3 = cv2.resize(img_3, (200,200))

# %%
rs_img_4 = cv2.resize(img_4, (200,200))

# %%
print(img_5)
# Out:
# [[[157 157 157]
#   [158 158 158]
#   [158 158 158]
#   ...
#   [203 203 203]
#   [202 202 202]
#   [201 201 201]]
#
#  [[158 158 158]
#   [158 158 158]
#   [158 158 158]
#   ...
#   [203 203 203]
#   [203 203 203]
#   [201 201 201]]
#
#  [[158 158 158]
#   [158 158 158]
#   [159 159 159]
#   ...
#   [203 203 203]
#   [203 203 203]
#   [202 202 202]]
#
#  ...
#
#  [[194 193 195]
#   [194 193 195]
#   [194 193 195]
#   ...
#   [194 194 194]
#   [194 194 194]
#   [193 193 193]]
#
#  [[193 192 194]
#   [194 193 195]
#   [194 193 195]
#   ...
#   [194 194 194]
#   [193 193 193]
#   [193 193 193]]
#
#  [[191 191 191]
#   [191 191 191]
#   [192 192 192]
#   ...
#   [194 194 194]
#   [193 193 193]
#   [192 192 192]]]

# %%
rs_img_5 = cv2.resize(img_5, (100,100))

# %%
img_h_1 = np.hstack((rs_img_1 , rs_img_2))

# %%
img_h_2 = np.hstack((rs_img_3 , rs_img_4))

# %%
plt.imshow(img_h_1)
plt.show()

# %%
plt.imshow(img_h_2)
plt.show()

# %%
img_v = np.vstack((img_h_1, img_h_2))

# %%
plt.imshow(img_v)
plt.show()

# %%
img_v_rgb = cv2.cvtColor(img_v , cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_v_rgb)

# %%
black = (0,0,0)
br_img_1 = cv2.copyMakeBorder(rs_img_1,10,5,10,5,cv2.BORDER_CONSTANT,value=black)

# %%
plt.imshow(br_img_1)

# %%
br_img_2 = cv2.copyMakeBorder(rs_img_2,10,5,5,10,cv2.BORDER_CONSTANT,value=black)
plt.imshow(br_img_2)

# %%
br_img_3 = cv2.copyMakeBorder(rs_img_3,5,10,10,5,cv2.BORDER_CONSTANT,value=black)
plt.imshow(br_img_3)

# %%
br_img_4 = cv2.copyMakeBorder(rs_img_4,5,10,5,10,cv2.BORDER_CONSTANT,value=black)
plt.imshow(br_img_4)

# %%
br_img_h_1 = np.hstack((br_img_1 , br_img_2))
br_img_h_2 = np.hstack((br_img_3 , br_img_4))
br_img_v = np.vstack((br_img_h_1 , br_img_h_2))
plt.imshow(br_img_v)

# %%
br_img_v_rgb = cv2.cvtColor(br_img_v , cv2.COLOR_BGR2RGB)

# %%
plt.imshow(br_img_v_rgb)
