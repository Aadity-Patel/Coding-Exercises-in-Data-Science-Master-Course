# %% [markdown]
# ### 1. Importing OpenCV

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('5_2_balbasaur.jpg')

# %%
plt.imshow(img)

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(img)
plt.show()
plt.axis("Off") //Not working??
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb_img)
plt.show()

# %%
img_px = cv2.resize(rgb_img,(100,100))

# %%
plt.imshow(img_px)
plt.show()
